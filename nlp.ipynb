# %% [markdown]
# <a href="https://colab.research.google.com/github/yeojun6/21-2phonetics/blob/main/nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# nlp = natural language processing

# %% [markdown]
# ### Tokenization 어떤 문장, 문단을 단어별로 쪼갬

# %%
import nltk

# %%
text = 'Here’s to the crazy ones, the misfits, the rebels, the troublemakers, the round pegs in the square holes. \
The ones who see things differently — they’re not fond of rules. \
You can quote them, disagree with them, glorify or vilify them, \
but the only thing you can’t do is ignore them because they change things. \
They push the human race forward, and while some may see them as the crazy ones, we see genius, \
because the ones who are crazy enough to think that they can change the world, are the ones who do.'

# %%
type(text) #type: string
len(text) #길이: 505
text[0:10] #text indexing: 0부터 "9"까지의 텍스트
#text[:10] #콜론 앞에 아무것도 없으면 제일 첫번째부터 시작한다는 의미.
#text[:] #텍스트 처음부터 끝까지
# text[:-1] #-1은 맨 뒤에서 첫 번째(.) == -1인 .은 포함하지 않고 그 전까지 보여주는 공식
# Out:
# 'Here’s to '

# %%
text.split() #split: 스페이스 기반에 따라 나누기
# Out:
# ['Here’s',
#  'to',
#  'the',
#  'crazy',
#  'ones,',
#  'the',
#  'misfits,',
#  'the',
#  'rebels,',
#  'the',
#  'troublemakers,',
#  'the',
#  'round',
#  'pegs',
#  'in',
#  'the',
#  'square',
#  'holes.',
#  'The',
#  'ones',
#  'who',
#  'see',
#  'things',
#  'differently',
#  '—',
#  'they’re',
#  'not',
#  'fond',
#  'of',
#  'rules.',
#  'You',
#  'can',
#  'quote',
#  'them,',
#  'disagree',
#  'with',
#  'them,',
#  'glorify',
#  'or',
#  'vilify',
#  'them,',
#  'but',
#  'the',
#  'only',
#  'thing',
#  'you',
#  'can’t',
#  'do',
#  'is',
#  'ignore',
#  'them',
#  'because',
#  'they',
#  'change',
#  'things.',
#  'They',
#  'push',
#  'the',
#  'human',
#  'race',
#  'forward,',
#  'and',
#  'while',
#  'some',
#  'may',
#  'see',
#  'them',
#  'as',
#  'the',
#  'crazy',
#  'ones,',
#  'we',
#  'see',
#  'genius,',
#  'because',
#  'the',
#  'ones',
#  'who',
#  'are',
#  'crazy',
#  'enough',
#  'to',
#  'think',
#  'that',
#  'they',
#  'can',
#  'change',
# ...

# %%
type(text.split())
# Out:
# list

# %%
words = text.split()
''.join(words)
# Out:
# 'Here’stothecrazyones,themisfits,therebels,thetroublemakers,theroundpegsinthesquareholes.Theoneswhoseethingsdifferently—they’renotfondofrules.Youcanquotethem,disagreewiththem,glorifyorvilifythem,buttheonlythingyoucan’tdoisignorethembecausetheychangethings.Theypushthehumanraceforward,andwhilesomemayseethemasthecrazyones,weseegenius,becausetheoneswhoarecrazyenoughtothinkthattheycanchangetheworld,aretheoneswhodo.'

# %%
from nltk.tokenize import word_tokenize #마침표, 쉼표 등까지 유려하게 tokenize
nltk.download('punkt')
words = word_tokenize(text)
words
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['Here',
#  '’',
#  's',
#  'to',
#  'the',
#  'crazy',
#  'ones',
#  ',',
#  'the',
#  'misfits',
#  ',',
#  'the',
#  'rebels',
#  ',',
#  'the',
#  'troublemakers',
#  ',',
#  'the',
#  'round',
#  'pegs',
#  'in',
#  'the',
#  'square',
#  'holes',
#  '.',
#  'The',
#  'ones',
#  'who',
#  'see',
#  'things',
#  'differently',
#  '—',
#  'they',
#  '’',
#  're',
#  'not',
#  'fond',
#  'of',
#  'rules',
#  '.',
#  'You',
#  'can',
#  'quote',
#  'them',
#  ',',
#  'disagree',
#  'with',
#  'them',
#  ',',
#  'glorify',
#  'or',
#  'vilify',
#  'them',
#  ',',
#  'but',
#  'the',
#  'only',
#  'thing',
#  'you',
#  'can',
#  '’',
#  't',
#  'do',
#  'is',
#  'ignore',
#  'them',
#  'because',
#  'they',
#  'change',
#  'things',
#  '.',
#  'They',
#  'push',
#  'the',
#  'human',
#  'race',
#  'forward',
#  ',',
#  'and',
#  'while',
#  'some',
#  'may',
#  'see',
# ...

# %%
from nltk.tokenize import RegexpTokenizer #RegularExpressionTokenizer: 어떤 표현이 있는 어구
retokenize = RegexpTokenizer("[\w]+") #[/w]+는 알파벳과 숫자 하나 이상 = 단어의 정의 
words = retokenize.tokenize(text)
words
# Out:
# ['Here',
#  's',
#  'to',
#  'the',
#  'crazy',
#  'ones',
#  'the',
#  'misfits',
#  'the',
#  'rebels',
#  'the',
#  'troublemakers',
#  'the',
#  'round',
#  'pegs',
#  'in',
#  'the',
#  'square',
#  'holes',
#  'The',
#  'ones',
#  'who',
#  'see',
#  'things',
#  'differently',
#  'they',
#  're',
#  'not',
#  'fond',
#  'of',
#  'rules',
#  'You',
#  'can',
#  'quote',
#  'them',
#  'disagree',
#  'with',
#  'them',
#  'glorify',
#  'or',
#  'vilify',
#  'them',
#  'but',
#  'the',
#  'only',
#  'thing',
#  'you',
#  'can',
#  't',
#  'do',
#  'is',
#  'ignore',
#  'them',
#  'because',
#  'they',
#  'change',
#  'things',
#  'They',
#  'push',
#  'the',
#  'human',
#  'race',
#  'forward',
#  'and',
#  'while',
#  'some',
#  'may',
#  'see',
#  'them',
#  'as',
#  'the',
#  'crazy',
#  'ones',
#  'we',
#  'see',
#  'genius',
#  'because',
#  'the',
#  'ones',
#  'who',
#  'are',
#  'crazy',
#  'enough',
#  'to',
#  'think',
#  'that',
#  'they',
#  'can',
#  'change',
# ...

# %% [markdown]
# ### Normalization 변이형태
# Stemming: am → am, the going → the go, having → hav #그냥 끊기
#
# Lemmatization: am → be, the going → the going, having → have #원형

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
stemmer.stem(words[0])
# Out:
# 'here'

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
[stemmer.stem(w) for w in words] #대괄호는 list 표시한 것
# Out:
# ['I',
#  'am',
#  'john',
#  'from',
#  'america',
#  'and',
#  'would',
#  'like',
#  'to',
#  'go',
#  'to',
#  'starbuck']

# %%
from nltk.stem import LancasterStemmer
stemmer = LancasterStemmer()
[stemmer.stem(w) for w in words]
# Out:
# ['i',
#  'am',
#  'john',
#  'from',
#  'americ',
#  'and',
#  'would',
#  'lik',
#  'to',
#  'go',
#  'to',
#  'starbuck']

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
[lemmatizer.lemmatize(w) for w in words]
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# ['Here',
#  's',
#  'to',
#  'the',
#  'crazy',
#  'one',
#  'the',
#  'misfit',
#  'the',
#  'rebel',
#  'the',
#  'troublemaker',
#  'the',
#  'round',
#  'peg',
#  'in',
#  'the',
#  'square',
#  'hole',
#  'The',
#  'one',
#  'who',
#  'see',
#  'thing',
#  'differently',
#  'they',
#  're',
#  'not',
#  'fond',
#  'of',
#  'rule',
#  'You',
#  'can',
#  'quote',
#  'them',
#  'disagree',
#  'with',
#  'them',
#  'glorify',
#  'or',
#  'vilify',
#  'them',
#  'but',
#  'the',
#  'only',
#  'thing',
#  'you',
#  'can',
#  't',
#  'do',
#  'is',
#  'ignore',
#  'them',
#  'because',
#  'they',
#  'change',
#  'thing',
#  'They',
#  'push',
#  'the',
#  'human',
#  'race',
#  'forward',
#  'and',
#  'while',
#  'some',
#  'may',
#  'see',
#  'them',
#  'a',
#  'the',
#  'crazy',
#  'one',
#  'we',
#  'see',
#  'genius',
#  'because',
#  'the',
#  'one',
#  'who',
#  'are',
# ...

# %% [markdown]
# ### Stopword
# 빈번하게 나오는 단어 카운트 하는 거 스탑

# %%
from nltk.corpus import stopwords  
nltk.download('stopwords')
stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
# ...

# %%
from nltk.corpus import stopwords  
nltk.download('stopwords')
print(words)
words = [w for w in words if not w in stopwords.words('english')] #각 루프에 대해서 스탑워드를 뺀다는 if를 만족시켜야 한다
print(words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['Here', 's', 'to', 'the', 'crazy', 'ones', 'the', 'misfits', 'the', 'rebels', 'the', 'troublemakers', 'the', 'round', 'pegs', 'in', 'the', 'square', 'holes', 'The', 'ones', 'who', 'see', 'things', 'differently', 'they', 're', 'not', 'fond', 'of', 'rules', 'You', 'can', 'quote', 'them', 'disagree', 'with', 'them', 'glorify', 'or', 'vilify', 'them', 'but', 'the', 'only', 'thing', 'you', 'can', 't', 'do', 'is', 'ignore', 'them', 'because', 'they', 'change', 'things', 'They', 'push', 'the', 'human', 'race', 'forward', 'and', 'while', 'some', 'may', 'see', 'them', 'as', 'the', 'crazy', 'ones', 'we', 'see', 'genius', 'because', 'the', 'ones', 'who', 'are', 'crazy', 'enough', 'to', 'think', 'that', 'they', 'can', 'change', 'the', 'world', 'are', 'the', 'ones', 'who', 'do']
# ...

# %% [markdown]
# **4번째 줄이 스탑워드 빠진 것! to, the 같은 단어가 3번째 줄에 비해 없어진 것이 보임

# %% [markdown]
# ### Collocation, Concordance
# 두 단어의 연쇄 / 예문 찾기

# %%
nltk.download('gutenberg')
text = nltk.corpus.gutenberg.raw('melville-moby_dick.txt')
text
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# ...

# %%
nltk.download('gutenberg')
text = nltk.corpus.gutenberg.raw('melville-moby_dick.txt')
words = nltk.word_tokenize(text)
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!

# %%
nltk.Text(words).collocations() #collocation: 빈번하게 나오는 두 단어
# Out:
# Sperm Whale; Moby Dick; White Whale; old man; Captain Ahab; sperm
# whale; Right Whale; Captain Peleg; Mr. Starbuck; New Bedford; Cape
# Horn; 'ye see; cried Ahab; years ago; lower jaw; white whale; Mrs.
# Hussey; chief mate; never mind; Father Mapple

# %%
nltk.Text(words).concordance('great', 10, 10) #앞의 10: great를 포함해서 양쪽 합쳐서 9자(공백포함) #뒤의 10: 그런 게 총 10개
# Out:
# Displaying 10 of 303 matches:
# d great w
# a great f
# d great ,
# l great s
# a great m
# y great v
# n great s
# e great L
# t great L
# a great d

# %% [markdown]
# ### Collocation, Concordance2

# %%
nltk.download('gutenberg')
text = nltk.corpus.gutenberg.raw('austen-emma.txt')
words = retokenize.tokenize(text)
text
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# ...

# %%
nltk.Text(words).concordance('Emma', 79, 10) #소설 속 해당 단어의 용법(어떻게 쓰이는가)
# Out:
# Displaying 10 of 865 matches:
#                                      Emma by Jane Austen 1816 VOLUME I CHAPTER
#                                      Emma Woodhouse handsome clever and rich w
# f both daughters but particularly of Emma Between _them_ it was more the intim
# nd friend very mutually attached and Emma doing just what she liked highly est
#  by her own The real evils indeed of Emma s situation were the power of having
# ding day of this beloved friend that Emma first sat in mournful thought of any
# going only half a mile from them but Emma was aware that great must be the dif
# a day It was a melancholy change and Emma could not but sigh over it and wish
# ll the rest of her life at Hartfield Emma smiled and chatted as cheerfully as
# l be able to tell her how we all are Emma spared no exertions to maintain this

# %%
len(words)
# Out:
# 161983

# %%
nltk.Text(words).dispersion_plot(["Emma", "Knightley", "Frank", "Jane", "Harriet", "Robert"])

# %%
nltk.Text(words).similar("Emma")
# Out:
# she it he i harriet you her jane him that me and all they them herself
# there but be isabella

# %%
nltk.Text(words).common_contexts(["Emma", "she"]) #비슷한 맥락에서 두 단어가 쓰이는 상황. 언더스코어에 emma, she 둘 다 들어감
# Out:
# but_was and_could that_should said_and which_could whom_knew
# which_particularly and_imagined that_could said_i that_began
# and_thought do_was but_could than_had said_but manner_was this_could
# as_saw possible_could

# %% [markdown]
# ### Frequency distribution, Frequency plot
# 단어 나오는 빈도수

# %%
fd = nltk.FreqDist(words).most_common(10) #가장 빈번하게 나온 단어 top 10개: ('of'는 6513번 나오고... etc)
fd
# Out:
# [('to', 5183),
#  ('the', 4844),
#  ('and', 4672),
#  ('of', 4279),
#  ('I', 3178),
#  ('a', 3004),
#  ('was', 2385),
#  ('her', 2381),
#  ('it', 2128),
#  ('in', 2118)]

# %%
nltk.Text(words).plot(20)

# %% [markdown]
# ### Dictionary

# %%
nltk.download('words')
a = nltk.corpus.words.words('en') #en: english
a[:20] #0번째부터 19번째까지
#a[-20:] #뒤에서 20개 보여줌
#a[-20:-1] #끝ㄱ에서 맨 마지막 것 빼고 19개
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# ['A',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'Aani',
#  'aardvark',
#  'aardwolf',
#  'Aaron',
#  'Aaronic',
#  'Aaronical',
#  'Aaronite',
#  'Aaronitic',
#  'Aaru',
#  'Ab',
#  'aba',
#  'Ababdeh',
#  'Ababua',
#  'abac']

# %%
nltk.download('words')
nltk.corpus.words.words('en')[:20]
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# ['A',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'Aani',
#  'aardvark',
#  'aardwolf',
#  'Aaron',
#  'Aaronic',
#  'Aaronical',
#  'Aaronite',
#  'Aaronitic',
#  'Aaru',
#  'Ab',
#  'aba',
#  'Ababdeh',
#  'Ababua',
#  'abac']

# %%
len(nltk.corpus.words.words('en'))
# Out:
# 235886

# %% [markdown]
# ### Regular expression
# 규칙 표현. "~~한 단어를 찾아라."

# %%
import re

# %%
'''       Basic Regular Expression Meta-Characters, Including Wildcards, Ranges and Closures

.	        Wildcard, matches any character
^abc	    Matches some pattern abc at the start of a string #string앞에서 찾기
abc$	    Matches some pattern abc at the end of a string #string뒤에서 찾기
[abc]	    Matches one of a set of characters
[^abc]    Matches anything but a set of characters
[A-Z0-9]	Matches one of a range of characters
ed|ing|s	Matches one of the specified strings (disjunction)
*	        Zero or more of previous item, e.g. a*, [a-z]* (also known as Kleene Closure) #0개 이상
+	        One or more of previous item, e.g. a+, [a-z]+ #1개 이상
?	        Zero or one of the previous item (i.e. optional), e.g. a?, [a-z]?
{n}	      Exactly n repeats where n is a non-negative integer
{n,}	    At least n repeats
{,n}	    No more than n repeats
{m,n}	    At least m and no more than n repeats
a(b|c)+	  Parentheses that indicate the scope of the operators
(...)     Matches whatever regular expression is inside the parentheses
\d
Matches any decimal digit; this is equivalent to the class [0-9].
\D
Matches any non-digit character; this is equivalent to the class [^0-9].
\s
Matches any whitespace character; this is equivalent to the class [ \t\n\r\f\v].
\S
Matches any non-whitespace character; this is equivalent to the class [^ \t\n\r\f\v].
\w
Matches any alphanumeric character; this is equivalent to the class [a-zA-Z0-9_].
\W
Matches any non-alphanumeric character; this is equivalent to the class [^a-zA-Z0-9_].

'''
# Out:
# '       Basic Regular Expression Meta-Characters, Including Wildcards, Ranges and Closures\n\n.\t        Wildcard, matches any character\n^abc\t    Matches some pattern abc at the start of a string #string앞에서 찾기\nabc$\t    Matches some pattern abc at the end of a string #string뒤에서 찾기\n[abc]\t    Matches one of a set of characters\n[^abc]    Matches anything but a set of characters\n[A-Z0-9]\tMatches one of a range of characters\ned|ing|s\tMatches one of the specified strings (disjunction)\n*\t        Zero or more of previous item, e.g. a*, [a-z]* (also known as Kleene Closure) #0개 이상\n+\t        One or more of previous item, e.g. a+, [a-z]+ #1개 이상\n?\t        Zero or one of the previous item (i.e. optional), e.g. a?, [a-z]?\n{n}\t      Exactly n repeats where n is a non-negative integer\n{n,}\t    At least n repeats\n{,n}\t    No more than n repeats\n{m,n}\t    At least m and no more than n repeats\na(b|c)+\t  Parentheses that indicate the scope of the operators\n(...)     Matches wh
# ...

# %%
word = 'supercalifragilistiexpialidocious'
re.search('[aeiou]li', word) #'[aeiou]중에 하나와+li' 조합을 단어에서 찾아라
# Out:
# <re.Match object; span=(6, 9), match='ali'>

# %% [markdown]
# 해당 조합은 superc'ALI'...에 있으므로 단어의 6부터 9사이에 있다

# %%
re.search('ed$', 'considered') #considered 이라는 string에서 앞의 규칙을 찾아라
# Out:
# <re.Match object; span=(8, 10), match='ed'>

# %%
re.findall('ed', 'considered seed')
# Out:
# ['ed', 'ed']

# %%
re.findall('[cd]', 'considered condo')
# Out:
# ['c', 'd', 'd', 'c', 'd']

# %%
re.findall('[a-z/s]', 'considered condo')
# Out:
# ['c', 'o', 'n', 's', 'i', 'd', 'e', 'r', 'e', 'd', 'c', 'o', 'n', 'd', 'o']

# %%
engdict = nltk.corpus.words.words('en')

result = [w for w in engdict if re.search('ed$', w)]
# result = [w for w in engdict if re.search('^..j..t..$', w)]
# result = [w for w in engdict if re.search('^[ghi][mno][jlk][def]$', w)]
# result = [w for w in engdict if re.search('^[ah]+$', w)][:10]
print(result[:10])
# Out:
# ['abaissed', 'abandoned', 'abased', 'abashed', 'abatised', 'abed', 'aborted', 'abridged', 'abscessed', 'absconded']

# %%
engdict = nltk.corpus.words.words('en')

# result = [w for w in engdict if re.search('ed$', w)]
result = [w for w in engdict if re.search('^..j..t..$', w)] #00j00t인 단어(j가 3번째 철자이고 t가 여섯 번째 철자)
# result = [w for w in engdict if re.search('^[ghi][mno][jlk][def]$', w)]
# result = [w for w in engdict if re.search('^[ah]+$', w)][:10]
print(result[:10])
# Out:
# ['abjectly', 'adjuster', 'dejected', 'dejectly', 'injector', 'majestic', 'objectee', 'objector', 'rejecter', 'rejector']

# %%
engdict = nltk.corpus.words.words('en')

# result = [w for w in engdict if re.search('ed$', w)]
# result = [w for w in engdict if re.search('^..j..t..$', w)]
result = [w for w in engdict if re.search('^[ghi][mno][jlk][def]$', w)] #각 괄호 속 하나씩 골라서 만든 단어
# result = [w for w in engdict if re.search('^[ah]+$', w)][:10]
print(result[:10])
# Out:
# ['gold', 'golf', 'hold', 'hole']

# %%
engdict = nltk.corpus.words.words('en')

# result = [w for w in engdict if re.search('ed$', w)]
# result = [w for w in engdict if re.search('^..j..t..$', w)]
# result = [w for w in engdict if re.search('^[ghi][mno][jlk][def]$', w)]
result = [w for w in engdict if re.search('^[ah]+$', w)] #a 혹은 h 문자가 하나 이상(+)
print(result[:10])
# Out:
# ['a', 'aa', 'ah', 'aha', 'h', 'ha', 'hah']

# %%
nltk.download('treebank')
wsj = nltk.corpus.treebank.words() #WallStreetJournal

result = [w for w in wsj if re.search('(ed|ing)$', w)]
# result = [w for w in wsj if re.search('^[0-9]+\.[0-9]+$', w)] #소수점 찾기
# result = [w for w in wsj if re.search('^[A-Z]+\$$', w)] #대문자 알파벳 하나 이상으로 시작하고 달러($)표시로 끝나는 단어
# result = [w for w in wsj if re.search('^[0-9]{4}$', w)] #숫자 4개짜리
# result = [w for w in wsj if re.search('^[0-9]+-[a-z]{3,5}$', w)] #숫자 1개이상 나오고 대시 나오고 소문자가 3개에서 5개
# result = [w for w in wsj if re.search('^[a-z]{5,}-[a-z]{2,3}-[a-z]{,6}$', w)] #소문자가 5개 이상나오고 대시 나오고 소문자가 2개 혹은 3개 대시 나오고 소문자 6개 이하 단어

result = sorted(set(result)) #result를 set로 바꾸고 sort하라
print(result[:10])
# Out:
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# ['62%-owned', 'Absorbed', 'According', 'Adopting', 'Advanced', 'Advancing', 'Alfred', 'Allied', 'Annualized', 'Anything']

# %% [markdown]
# ### Extract information (pos tag, named entity)
# **POS(part of speech) tag: 품사 분류
#
# **named entity: 어떤 카테고리 안에 분류(name, location...)

# %%
sent = "I am John from America and would like to go to Starbucks"
words = nltk.word_tokenize(sent)

# %%
'''
POS tag list:

CC	coordinating conjunction
CD	cardinal digit
DT	determiner
EX	existential there (like: "there is" ... think of it like "there exists")
FW	foreign word
IN	preposition/subordinating conjunction
JJ	adjective	'big'
JJR	adjective, comparative	'bigger'
JJS	adjective, superlative	'biggest'
LS	list marker	1)
MD	modal	could, will
NN	noun, singular 'desk'
NNS	noun plural	'desks'
NNP	proper noun, singular	'Harrison'
NNPS	proper noun, plural	'Americans'
PDT	predeterminer	'all the kids'
POS	possessive ending	parent's
PRP	personal pronoun	I, he, she
PRP$	possessive pronoun	my, his, hers
RB	adverb	very, silently,
RBR	adverb, comparative	better
RBS	adverb, superlative	best
RP	particle	give up
TO	to	go 'to' the store.
UH	interjection	errrrrrrrm
VB	verb, base form	take
VBD	verb, past tense	took
VBG	verb, gerund/present participle	taking
VBN	verb, past participle	taken
VBP	verb, sing. present, non-3d	take
VBZ	verb, 3rd person sing. present	takes
WDT	wh-determiner	which
WP	wh-pronoun	who, what
WP$	possessive wh-pronoun	whose
WRB	wh-abverb	where, when
'''
# Out:
# '\nPOS tag list:\n\nCC\tcoordinating conjunction\nCD\tcardinal digit\nDT\tdeterminer\nEX\texistential there (like: "there is" ... think of it like "there exists")\nFW\tforeign word\nIN\tpreposition/subordinating conjunction\nJJ\tadjective\t\'big\'\nJJR\tadjective, comparative\t\'bigger\'\nJJS\tadjective, superlative\t\'biggest\'\nLS\tlist marker\t1)\nMD\tmodal\tcould, will\nNN\tnoun, singular \'desk\'\nNNS\tnoun plural\t\'desks\'\nNNP\tproper noun, singular\t\'Harrison\'\nNNPS\tproper noun, plural\t\'Americans\'\nPDT\tpredeterminer\t\'all the kids\'\nPOS\tpossessive ending\tparent\'s\nPRP\tpersonal pronoun\tI, he, she\nPRP$\tpossessive pronoun\tmy, his, hers\nRB\tadverb\tvery, silently,\nRBR\tadverb, comparative\tbetter\nRBS\tadverb, superlative\tbest\nRP\tparticle\tgive up\nTO\tto\tgo \'to\' the store.\nUH\tinterjection\terrrrrrrrm\nVB\tverb, base form\ttake\nVBD\tverb, past tense\ttook\nVBG\tverb, gerund/present participle\ttaking\nVBN\tverb, past participle\ttaken\nVBP\tverb, sing
# ...

# %%
nltk.download('averaged_perceptron_tagger')
pos = nltk.pos_tag(words)
pos
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [('I', 'PRP'),
#  ('am', 'VBP'),
#  ('John', 'NNP'),
#  ('from', 'IN'),
#  ('America', 'NNP'),
#  ('and', 'CC'),
#  ('would', 'MD'),
#  ('like', 'VB'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('to', 'TO'),
#  ('Starbucks', 'VB')]

# %%
nltk.download('maxent_ne_chunker')
NE = nltk.ne_chunk(pos) #ne: named entity
# common Entity types: ORGANIZATION, PERSON, LOCATION, DATE, TIME, MONEY, and GPE (geo-political entity)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.

# %%
print(NE)
# Out:
# (S
#   I/PRP
#   am/VBP
#   (PERSON John/NNP)
#   from/IN
#   (GPE America/NNP)
#   and/CC
#   would/MD
#   like/VB
#   to/TO
#   go/VB
#   to/TO
#   Starbucks/VB)

# %% [markdown]
# named entity ... intention - 정보의 종류
#
# -공부하러 고려대에 간다. named entity:고려대 / intention: 공부하러

# %% [markdown]
# ### Wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

text = nltk.corpus.gutenberg.raw('bible-kjv.txt')

wc = WordCloud().generate(text) 
plt.imshow(wc)

# %%
stopwords = set(STOPWORDS) 
stopwords.add('unto') #unto제외시키기
wc = WordCloud(stopwords = stopwords).generate(text) 
plt.imshow(wc)
